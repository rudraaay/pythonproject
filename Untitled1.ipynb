# 44   154  35.52   77.74  11  47  18
# 45  188*  40.95   72.04  13  45  11
# 46   145  35.34   74.59   4  55  13
# 47  189*     47    90.2  11  45   7
# 48  237*   42.2   87.34  16  35  15
# 49  140*   32.9   76.61  11  38  19

# %%
df.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'SR', '100',
#        '50', '0'],
#       dtype='object')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#                         Player       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144  33.37
#
#       SR 100  50   0
# 0  86.23  49  96  20
# 1  78.86  25  93  15
# 2  80.39  30  82  20
# 3   91.2  28  68  34
# 4  78.96  19  77  28
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Mat'].plot(kind='hist', bins=20, title='Mat')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Player').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('Span').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('Inns').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('NO').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['Mat'].plot(kind='line', figsize=(8, 4), title='Mat')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Span'].value_counts()
#     for x_label, grp in _df_6.groupby('Player')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Player')
# _ = plt.ylabel('Span')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Inns'].value_counts()
#     for x_label, grp in _df_7.groupby('Span')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Span')
# _ = plt.ylabel('Inns')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['NO'].value_counts()
#     for x_label, grp in _df_8.groupby('Inns')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Inns')
# _ = plt.ylabel('NO')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Runs'].value_counts()
#     for x_label, grp in _df_9.groupby('NO')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('NO')
# _ = plt.ylabel('Runs')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_10['Player'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_10, x='Mat', y='Player', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_11['Span'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_11, x='Mat', y='Span', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_12['Inns'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_12, x='Mat', y='Inns', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_13['NO'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_13, x='Mat', y='NO', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df.head(20).groupby('SR').mean().plot(kind='bar')
# Out:
# <ipython-input-34-0f3863389c80>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.head(20).groupby('SR').mean().plot(kind='bar')
# <Axes: xlabel='SR'>

# %%
df['Mat'].head(10).hist(bins=10)
# Out:
# <Axes: >

# %%
df.head(20).groupby('Mat').mean().plot(kind='bar')
# Out:
# <ipython-input-91-1a5d0945a4e6>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.head(20).groupby('Mat').mean().plot(kind='bar')
# <Axes: xlabel='Mat'>

# %%
plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
df.head(200).groupby('Mat').mean().plot(kind='bar')
plt.xlabel('Matches')
plt.ylabel('Average')
plt.subplot(2, 2, 2)
df.head(20).groupby('NO').mean().plot(kind='bar')
plt.xlabel('Not Outs')
plt.ylabel('Average')
plt.show()
# Out:
# <ipython-input-94-fe92cd87147f>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.head(200).groupby('Mat').mean().plot(kind='bar')
# <ipython-input-94-fe92cd87147f>:8: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 2, 2)
# <ipython-input-94-fe92cd87147f>:9: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.head(20).groupby('NO').mean().plot(kind='bar')
